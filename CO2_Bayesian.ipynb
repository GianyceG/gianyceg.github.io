# %%
# !pip install arviz
# !pip install tensorflow tensorflow-probability
# !pip install pymc
# Out:
# Requirement already satisfied: arviz in c:\users\gesua\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: setuptools>=60.0.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (3.8.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (1.26.4)
# Requirement already satisfied: scipy>=1.9.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (1.11.4)
# Requirement already satisfied: packaging in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (23.1)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (2.1.4)
# Requirement already satisfied: xarray>=2022.6.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (2023.6.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (1.4.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (4.9.0)
# Requirement already satisfied: xarray-einstats>=0.3 in c:\users\gesua\anaconda3\lib\site-packages (from arviz) (0.8.0)
# Requirement already satisfied: h5py in c:\users\gesua\anaconda3\lib\site-packages (from h5netcdf>=1.0.2->arviz) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gesua\anaconda3\lib\site-packages (from pandas>=1.5.0->arviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gesua\anaconda3\lib\site-packages (from pandas>=1.5.0->arviz) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gesua\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->arviz) (1.16.0)
# Requirement already satisfied: tensorflow in c:\users\gesua\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-probability in c:\users\gesua\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: decorator in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-probability) (2.2.1)
# Requirement already satisfied: dm-tree in c:\users\gesua\anaconda3\lib\site-packages (from tensorflow-probability) (0.1.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gesua\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\gesua\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in c:\users\gesua\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\gesua\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gesua\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gesua\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gesua\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gesua\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gesua\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gesua\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gesua\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gesua\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gesua\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gesua\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gesua\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.0)
# Requirement already satisfied: pymc in c:\users\gesua\anaconda3\lib\site-packages (5.17.0)
# Requirement already satisfied: arviz>=0.13.0 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (0.20.0)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (4.2.2)
# Requirement already satisfied: cloudpickle in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (2.2.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (1.26.4)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (2.1.4)
# Requirement already satisfied: pytensor<2.26,>=2.25.1 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (2.25.5)
# Requirement already satisfied: rich>=13.7.1 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (13.9.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (1.11.4)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\gesua\anaconda3\lib\site-packages (from pymc) (4.9.0)
# Requirement already satisfied: setuptools>=60.0.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (3.8.0)
# Requirement already satisfied: packaging in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (23.1)
# Requirement already satisfied: xarray>=2022.6.0 in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (2023.6.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (1.4.0)
# Requirement already satisfied: xarray-einstats>=0.3 in c:\users\gesua\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc) (0.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gesua\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gesua\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gesua\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2023.3)
# Requirement already satisfied: filelock>=3.15 in c:\users\gesua\anaconda3\lib\site-packages (from pytensor<2.26,>=2.25.1->pymc) (3.16.1)
# Requirement already satisfied: etuples in c:\users\gesua\anaconda3\lib\site-packages (from pytensor<2.26,>=2.25.1->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in c:\users\gesua\anaconda3\lib\site-packages (from pytensor<2.26,>=2.25.1->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in c:\users\gesua\anaconda3\lib\site-packages (from pytensor<2.26,>=2.25.1->pymc) (1.0.3)
# Requirement already satisfied: cons in c:\users\gesua\anaconda3\lib\site-packages (from pytensor<2.26,>=2.25.1->pymc) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gesua\anaconda3\lib\site-packages (from rich>=13.7.1->pymc) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gesua\anaconda3\lib\site-packages (from rich>=13.7.1->pymc) (2.15.1)
# Requirement already satisfied: h5py in c:\users\gesua\anaconda3\lib\site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gesua\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gesua\anaconda3\lib\site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\gesua\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.16.0)
# Requirement already satisfied: toolz in c:\users\gesua\anaconda3\lib\site-packages (from logical-unification->pytensor<2.26,>=2.25.1->pymc) (0.12.0)
# Requirement already satisfied: multipledispatch in c:\users\gesua\anaconda3\lib\site-packages (from logical-unification->pytensor<2.26,>=2.25.1->pymc) (0.6.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
import tensorflow as tf
import arviz as az
import matplotlib.pyplot as plt


# Load the CO2 data
file_path = r"C:\Users\gesua\Documents\Capstone_Project\Capstone\co2_mm_mlo.csv"
co2_data = pd.read_csv(file_path)

# Rename columns to match expected format and create a datetime column
co2_data.rename(columns={'year': 'year', 'date_month': 'month'}, inplace=True)

# Convert 'year' and 'month' into a datetime format
co2_data['date'] = pd.to_datetime(co2_data[['year', 'month']].assign(day=1))

# Plot the CO2 data
plt.figure(figsize=(10, 6))
plt.plot(co2_data['date'], co2_data['Monthly Average of CO2'], color='red', label='CO2 Concentration')

# Add labels and title
plt.title('Atmospheric CO2 at Mauna Loa Observatory')
plt.xlabel('Year')
plt.ylabel('CO2 mole fraction (ppm)')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
file_path = "C:/Users/gesua/Documents/Capstone_Project/Capstone/co2_mm_mlo.csv"
co2_data = pd.read_csv(file_path)

# Data Cleaning.
co2_data.rename(columns=lambda x: x.strip(), inplace=True)
co2_data['month'] = ((co2_data['decimal date'] % 1) * 12 + 1).astype(int)
co2_data['date'] = pd.to_datetime(co2_data[['year', 'month']].assign(day=1))
co2_data.set_index('date', inplace=True)

#Trend and Seasonality 
trend_all = np.linspace(0., 1., len(co2_data))[..., None]
trend_all = trend_all.astype(np.float32)
num_forecast_steps = 12  # Ensure num_forecast_steps is defined
trend = trend_all[:-num_forecast_steps, :]

# Create dummies for seasonality based on month
seasonality_all = pd.get_dummies(co2_data.index.month).values.astype(np.float32)
seasonality = seasonality_all[:-num_forecast_steps, :]

# Visualize
_, ax = plt.subplots(figsize=(12, 4))
X_subset = np.concatenate([trend, seasonality], axis=-1)[-50:]
im = ax.imshow(X_subset.T, aspect='auto', cmap='gray', interpolation='none')
plt.colorbar(im, ax=ax, orientation='horizontal')
ax.set_xticks([0, 12, 24, 36, 48])
ax.set_xticklabels(['2020', '2021', '2022', '2023', '2024'])
ax.set_yticks([0, 1])
ax.set_yticklabels(['Seasonality', 'Trend'])
plt.show()

# %%
tfd = tfp.distributions
root = tfd.JointDistributionCoroutine.Root

#Defining Time Series Model
@tfd.JointDistributionCoroutine
def ts_regression_model():
    intercept = yield root(tfd.Normal(0., 100., name="intercept"))
    trend_coeff = yield root(tfd.Normal(0., 10., name="trend_coeff"))
    seasonality_coeff = yield root(
        tfd.Sample(tfd.Normal(0., 1.),
                   sample_shape=seasonality.shape[-1],
                   name="seasonality_coeff"))
    noise = yield root(tfd.HalfCauchy(loc=0., scale=5., name="noise_sigma"))

    y_hat = (intercept[..., None] +
             tf.einsum("ij,...->...i", trend, trend_coeff) +
             tf.einsum("ij,...j->...i", seasonality, seasonality_coeff))

    yield tfd.Independent(
        tfd.Normal(y_hat, noise[..., None]),
        reinterpreted_batch_ndims=1,
        name="observed"
    )

model_instance = ts_regression_model

# Draw 100 prior samples
prior_samples = model_instance.sample(100)
prior_predictive_timeseries = prior_samples[-1]  # Use index-based access

# Plot the prior predictive samples
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(co2_data.index[:-num_forecast_steps],
        tf.transpose(prior_predictive_timeseries), alpha=0.5)
ax.set_xlabel("Year")
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# This code shows my uninformed prior of intercept ~ Normal(0,100). Meaning that this is a normal distribution of mean 0 and a large standard deviation 100.
# trend coefficient prior: trend_coeff ~ Normal(0,10) meaning that it is centered at 0 with s.d. 10.
# Seasonality prior: Assigned a normal prior with mean 0 and s.d. 1 for each seasonality component.
# Noise: half-cauchy distribution, it is constrained to be positive (bc, its s.d.) and allows for the possibility of larger noise levels.

# %% [markdown]
# Prior predictive samples from the simple regression model for the monthly CO2. Each line is one simulated time series, and they were uninformative priors, as they did not stem from the data set originally, but were applied general priors to follow with Gaussian distribution and are pre-defined parameters.

# %%
tfd = tfp.distributions
sts = tfp.sts

# Prepare Training and Test Data
train_end_date = '2023-12'
co2_training_data = co2_data.loc[:train_end_date, 'Monthly Average of CO2'].values.astype(np.float32)
dates_train = co2_data.index[:len(co2_training_data)]

co2_testing_data = co2_data.loc['2024-01':'2024-09', 'Monthly Average of CO2'].values.astype(np.float32)
dates_test = co2_data.index[len(co2_training_data):len(co2_training_data) + len(co2_testing_data)]

# Defining Bayesian Structural Time Series Model
model = sts.Sum(
    components=[
        sts.LocalLinearTrend(observed_time_series=co2_training_data),
        sts.Seasonal(num_seasons=12, observed_time_series=co2_training_data)
    ],
    observed_time_series=co2_training_data
)

# Variational Surrogate Posterior
variational_posteriors = tfp.sts.build_factored_surrogate_posterior(model=model)

optimizer = tf.optimizers.Adam(learning_rate=0.1)
tfp.vi.fit_surrogate_posterior(
    target_log_prob_fn=model.joint_log_prob(co2_training_data),
    surrogate_posterior=variational_posteriors,
    optimizer=optimizer,
    num_steps=200
)

# Forecast the Next 9 Months in 2024
forecast_dist = tfp.sts.forecast(
    model=model,
    observed_time_series=co2_training_data,
    parameter_samples=variational_posteriors.sample(50),
    num_steps_forecast=9
)

forecast_mean = forecast_dist.mean().numpy().squeeze()
forecast_index = pd.date_range(dates_train[-1] + pd.DateOffset(months=1), periods=9, freq="M")

#Plotting
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(dates_train, co2_training_data, label="Training Data", color="blue")
ax.plot(forecast_index, forecast_mean, label="Forecast for 2024", color="green")
ax.plot(dates_test, co2_testing_data, label="Actual Data (2024)", color="black")

ax.set_xlabel("Year")
ax.set_ylabel("Atmospheric CO2 concentration (ppm)")
ax.set_title("Training Data, Forecast, and Actual Data for 2024")
ax.legend(loc="upper left")

fig.autofmt_xdate()
plt.show()

#Calculate RMSE and MAPE for the Forecast vs Given Data
rmse = np.sqrt(np.mean((forecast_mean - co2_testing_data) ** 2))
mape = np.mean(np.abs((co2_testing_data - forecast_mean) / co2_testing_data)) * 100

print(f"RMSE: {rmse}")
print(f"MAPE: {mape}%")
# Out:
# RMSE: 0.6561658382415771
# MAPE: 0.1357398577965796%

# %% [markdown]
# The code indirectly respects Gaussian priors within the STS framework, but it does not give full control over the exact priors, as in a manually built Bayesian model.
# This code graphs the original, graphs the forecast into 2024, and then compares the graphs to the actual 2024 data.
